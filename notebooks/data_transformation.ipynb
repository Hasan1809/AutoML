# %%
import os

os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\hasan\\End to end\\AutoML'

# %%
from src.utils import load_object

# %%
validation_report = load_object(r"artifacts\09_09_2025_21_29\data_validation\report.json")

# %%
validation_report
# Out:
# {'actions': {'drop_columns': ['Cabin'],
#   'encoding': {'label_encode': ['Name', 'Ticket', 'Cabin'],
#    'one_hot': ['Sex', 'Embarked']},
#   'impute_columns': ['Age', 'Embarked'],
#   'remove_duplicates': False},
#  'column_analysis': {'Age': {'dtype': 'float64',
#    'missing_pct': 0.19865319865319866,
#    'unique_values': 88},
#   'Cabin': {'dtype': 'object',
#    'missing_pct': 0.7710437710437711,
#    'unique_values': 147},
#   'Embarked': {'dtype': 'object',
#    'missing_pct': 0.002244668911335578,
#    'unique_values': 3},
#   'Fare': {'dtype': 'float64', 'missing_pct': 0.0, 'unique_values': 248},
#   'Name': {'dtype': 'object', 'missing_pct': 0.0, 'unique_values': 891},
#   'Parch': {'dtype': 'int64', 'missing_pct': 0.0, 'unique_values': 7},
#   'PassengerId': {'dtype': 'int64', 'missing_pct': 0.0, 'unique_values': 891},
#   'Pclass': {'dtype': 'int64', 'missing_pct': 0.0, 'unique_values': 3},
#   'Sex': {'dtype': 'object', 'missing_pct': 0.0, 'unique_values': 2},
# ...

# %%
validation_report["target_analysis"]["type"]
# Out:
# 'categorical'

# %%
actions = validation_report.get("actions" , {})

# %%
actions
# Out:
# {'drop_columns': ['Cabin'],
#  'encoding': {'label_encode': ['Name', 'Ticket', 'Cabin'],
#   'one_hot': ['Sex', 'Embarked']},
#  'impute_columns': ['Age', 'Embarked'],
#  'remove_duplicates': False}
